# %%
##PyData Stack
import pandas as pd


##Utilities
import pickle
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Lab 1** <br>
# **Explaianble AI Spring 2025**
#
# **Total points:** 1 <br>
# **Overall Goal:** Brief excerise to practice loading data and models<br>
# **Date:** 01/23/2025
#
# **Notes:**
# * Complete in colab or on your own local jupyter notebook
# * Show to Instructor before leaving class -- Put a * by your name on attendance sheet

# %% [markdown]
# **1.** Using the files provided, load the test data into a pandas dataframe and display the head.

# %% [markdown]
# **2.** Using the files provided, load the model and predict classifications on the test file (using the .predict or .predict_proba functions)

# %%
data = pd.read_csv('test.csv')
data.head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0   0.046273   0.340907  -0.128987  -0.357010  -1.767848  -0.718455
# 1  -1.612041   0.449063   6.194156   2.001846   0.560136   0.097826
# 2   2.065491   0.201047  -4.242740  -1.586167   0.025822  -0.225761
# 3   1.421655  -0.107270  -1.776067  -1.095819  -1.142622  -0.144995
# 4   2.914657  -0.372360  -5.121467  -2.372488   1.901220   0.011902
#
#    feature_6  feature_7  feature_8  feature_9  feature_10  feature_11  \
# 0   2.768925   2.388471  -0.390895   2.006284   -2.495457   -0.030086
# 1   2.883177   2.758594   0.239062  -0.346056    3.215542    0.674718
# 2  -2.642713  -2.319762   0.135682   1.653271   -1.496966   -0.614976
# 3  -1.986565   0.014167  -0.366242   4.206505   -2.219218    0.841149
# 4  -1.097189  -5.124999   0.434811  -0.218324   -1.027039    0.867497
#
#    feature_12  feature_13  feature_14  feature_15  feature_16  feature_17  \
# ...

# %%
# Load the pickle file (update the filename if necessary)
with open("lab1_model.pkl", "rb") as f:
    model = pickle.load(f)

model
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %% [markdown]
# -
